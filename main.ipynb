# %%
from module.stock_csv_loader import StockCSVLoader
import glob

# %%
loader = StockCSVLoader(
    glob.glob("/Users/urachan/Desktop/dev/stock-analyze/data/quants/stock_price/*.csv")
)

input_features = loader.load()

# %%
input_features
# Out:
#             25030_LogDailyReturn  77010_LogDailyReturn  58030_LogDailyReturn  \
# Date
# 2014-06-03             -0.006125             -0.006543              0.004219
# 2014-06-04              0.001360              0.008753             -0.010471
# 2014-06-05              0.000678             -0.005485             -0.008368
# 2014-06-06             -0.008835              0.003295              0.002099
# 2014-06-09              0.006075             -0.008686             -0.006296
# ...                          ...                   ...                   ...
# 2024-05-27              0.005178              0.005378              0.035658
# 2024-05-28             -0.006544             -0.007978              0.011186
# 2024-05-29             -0.026484             -0.023722             -0.045618
# 2024-05-30              0.013716             -0.008101              0.004035
# 2024-05-31             -0.002296             -0.003191              0.000000
#
# ...

# %%
input_features.T.values
# Out:
# array([[-0.00612455,  0.00135962,  0.00067774, ..., -0.02648399,
#          0.01371636, -0.00229621],
#        [-0.0065431 ,  0.00875279, -0.00548548, ..., -0.02372221,
#         -0.00810119, -0.00319058],
#        [ 0.00421942, -0.0104713 , -0.00836825, ..., -0.04561828,
#          0.00403539,  0.        ],
#        ...,
#        [-0.01300731, -0.01125012, -0.01068185, ..., -0.01783878,
#         -0.01168214,  0.01278916],
#        [-0.00798635, -0.00344234,  0.00343446, ..., -0.01505529,
#          0.01138091,  0.01378698],
#        [-0.00364964,  0.00091785, -0.00183655, ...,  0.00213995,
#         -0.00648651,  0.00086693]])
